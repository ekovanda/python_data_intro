# %% [markdown]
# # Sortieren, Zählen, Aggregieren und erste Statistiken
# In der vorigen Lektion haben wir gelernt Daten einzulesen, zu filtern und Spalten zu bearbeiten. In diesem Kapitel lernen wir, mit Pandas erste Statistiken zu berechnen.

# %% [markdown]
# ## Einlesen der Daten
# Die Daten kommen von [Kaggle](https://www.kaggle.com/datasets/jealousleopard/goodreadsbooks).

# %%
import pandas as pd

# %%
df = pd.read_csv("books.csv", on_bad_lines="skip")

# %%
df.head(3)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
#
#   publication_date        publisher
# 0        9/16/2006  Scholastic Inc.
# 1         9/1/2004  Scholastic Inc.
# 2        11/1/2003       Scholastic

# %% [markdown]
# Bevor wir mit den Daten weiterarbeiten, beheben wir zunächst die offensichtlichen Fehler, damit wir das später nicht mehr tun müssen.
#
# **Prüfe zunächst die Anzahl der Zeilen, Spalten, sowie die Spaltenbezeichnungen, um dich mit dem Datensatz vertrauter zu machen**
#
# Hinweis: Wie das geht, hast du in der letzten Lektion gelernt

# %% [markdown]
# **Prüfe jetzt die Datentypen der Spalten. Auch das hast du in der letzten Lektion gelernt**

# %%
df.dtypes
# Out:
# bookID                  int64
# title                  object
# authors                object
# average_rating        float64
# isbn                   object
# isbn13                  int64
# language_code          object
#   num_pages             int64
# ratings_count           int64
# text_reviews_count      int64
# publication_date       object
# publisher              object
# dtype: object

# %% [markdown]
# Sieht eigentlich ganz gut aus. Zwei Kleinigkeiten sollten wir aber anpassen:
# - Das Erscheinungsdatum als Datum codieren, damit wir besser damit arbeiten können
# - Die `bookID` und `isbn` als String codieren, hiermit sind nämlich nicht die Zahlen gemeint sondern ein identifizierender Code. Bei solchen ist es empfehlenswert sie als String zu definieren.

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher
# 0        9/16/2006  Scholastic Inc.
# 1         9/1/2004  Scholastic Inc.
# 2        11/1/2003       Scholastic
# 3         5/1/2004  Scholastic Inc.
# 4        9/13/2004       Scholastic

# %%
df["publication_date"] = pd.to_datetime(df.publication_date, format='%m/%d/%Y', errors="coerce") # errors="coerce" setzen wir, weil es einzelne Felder gibt (z.B. 8177 welche keine valide Datumsangabe haben (31. November 2000))

# %% [markdown]
# **Versuche `bookID` und `isbn` als `str` zu codieren**
#
# Hinweis: Das hast du in der letzten Lektion gelernt.

# %%
# Dein Code hier

# %% [markdown]
# ## Sortieren
# In Pandas können wir problemlos nach einer oder mehreren Spalten sortieren. Aktuell ist das dataframe aufsteigend nach `bookID` sortiert. Stattdessen können wir aber beispielsweise nach Seitenzahl sortieren:

# %%
# Dieser Code sollte eigentlich funktionieren.
# Auf den zweiten Blick stellt sich heraus, dass in der Spaltenbezeichnung Leerzeichen versteckt sind. Das sollten wir beheben.
df.sort_values(by="num_pages")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-66a315fc0438> in <cell line: 3>()
#       1 # Dieser Code sollte eigentlich funktionieren.
#       2 # Auf den zweiten Blick hat sich herausgestellt, dass in der Spaltenbezeichnung Leerzeichen versteckt waren. Das sollten wir beheben.
# ----> 3 df.sort_values(by="num_pages")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# KeyError: 'num_pages'

# %%
df.columns
# Out:
# Index(['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13',
#        'language_code', '  num_pages', 'ratings_count', 'text_reviews_count',
#        'publication_date', 'publisher'],
#       dtype='object')

# %%
df = df.rename(columns={"  num_pages": "num_pages"})

# %%
# Jetzt funktioniert es
df.sort_values("num_pages").head(10)
# Out:
#        bookID                                              title  \
# 2765    10215                                  The Far Pavilions
# 2448     8916  The Complete Science Fiction Treasury of H.G. ...
# 8989    34938          First King of Shannara (Shannara Prequel)
# 8953    34706                                   13th Directorate
# 2676     9832           Blind Willow  Sleeping Woman: 24 Stories
# 2711     9981                                        Der Prozess
# 2732    10075                         Clockwork (Cover to Cover)
# 853      2835                   The Tragedy of Pudd'nhead Wilson
# 5298    19135                                       'Salem's Lot
# 10188   41273                     Fine Lines (One-Eyed Mack  #6)
#
#                                            authors  average_rating  \
# 2765                                     M.M. Kaye            4.21
# 2448                                    H.G. Wells            4.14
# 8989                                  Terry Brooks            3.96
# 8953                                  Barry Chubin            2.62
# 2676   Haruki Murakami/Ellen Archer/Patrick Lawlor            3.84
# 2711                                   Franz Kafka            3.98
# 2732                                Philip Pullman            3.87
# 853                    Mark Twain/Michael Prichard            3.79
# 5298                      Stephen King/Ron McLarty            4.02
# 10188                                   Jim Lehrer            3.23
#
#              isbn         isbn13 language_code  num_pages  ratings_count  \
# 2765   0517333414  9780517333419           eng          0             19
# 2448   0517052253  9780517052259           eng          0             45
# 8989   0517199963  9780517199961           eng          0              1
# 8953   0804104557  9780804104555           eng          0              8
# 2676   1400102952  9781400102952           eng          0             28
# 2711   0805232117  9780805232110           ger          0              2
# 2732   185549695X  9781855496958           eng          0             24
# 853    140015068X  9781400150687           eng          0              3
# 5298   0743536959  9780743536950         en-US          0             56
# 10188  0517164353  9780517164358           eng          0             17
#
#        text_reviews_count publication_date                      publisher
# 2765                    4       12/12/1988  Random House Value Publishing
# 2448                    1        6/24/1987  Random House Value Publishing
# 8989                    0        3/19/1996  Random House Value Publishing
# 8953                    1        2/28/1989                      Ivy Books
# 2676                    3       10/15/2006                   Tantor Media
# 2711                    0         5/5/1988                       Schocken
# 2732                    1        7/29/2002                 BBC Audiobooks
# 853                     0         1/1/2003                   Tantor Media
# 5298                    5        1/19/2004         Simon & Schuster Audio
# 10188                   4       11/19/1995  Random House Value Publishing

# %% [markdown]
# Standardmäßig sortiert `sort_values()` von aufsteigend. Stattdessen wollen wir aber die längsten Bücher zuerst sehen:

# %%
df.sort_values("num_pages", ascending=False).head()
# Out:
#        bookID                                           title  \
# 6497    24520  The Complete Aubrey/Maturin Novels (5 Volumes)
# 6802    25587                            The Second World War
# 10906   44613          Remembrance of Things Past (Boxed Set)
# 6          10    Harry Potter Collection (Harry Potter  #1-6)
# 6822    25709                        Summa Theologica  5 Vols
#
#                                                  authors  average_rating  \
# 6497                                     Patrick O'Brian            4.70
# 6802                    Winston S. Churchill/John Keegan            4.45
# 10906  Marcel Proust/C.K. Scott Moncrieff/Frederick A...            4.34
# 6                                           J.K. Rowling            4.73
# 6822                                      Thomas Aquinas            4.12
#
#              isbn         isbn13 language_code  num_pages  ratings_count  \
# 6497   039306011X  9780393060119           eng       6576           1338
# 6802   039541685X  9780395416853           eng       4736           1493
# 10906  0701125594  9780701125592           eng       3400              6
# 6      0439827604  9780439827607           eng       3342          28242
# 6822   0870610635  9780870610639           eng       3020           2734
#
#        text_reviews_count publication_date              publisher
# 6497                   81       10/17/2004  W. W. Norton  Company
# 6802                   99         5/9/1986          Mariner Books
# 10906                   1         3/5/1981        Chatto & Windus
# 6                     808        9/12/2005             Scholastic
# 6822                   84         1/1/1981     Christian Classics

# %% [markdown]
# Versuche es selbst. **Was sind die Bücher mit der besten Bewertung?**

# %%
# Dein Code hier

# %% [markdown]
# **Bonusaufgabe: Viele dieser Bücher haben sehr wenige Bewertungen. Was sind die 10 besten Bücher mit mindestens 1000 Bewertungen?**

# %%
# Dein Code hier
# Out:
#       bookID                                              title  \
# 6587   24812                     The Complete Calvin and Hobbes
# 4          8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 6589   24814      It's a Magical World (Calvin and Hobbes  #11)
# 6         10       Harry Potter Collection (Harry Potter  #1-6)
# 6590   24816  Homicidal Psycho Jungle Cat (Calvin and Hobbes...
# 6593   24820  Calvin and Hobbes: Sunday Pages 1985-1995: An ...
# 6497   24520     The Complete Aubrey/Maturin Novels (5 Volumes)
# 5614   20749                                   Study Bible: NIV
# 6591   24818                           The Days Are Just Packed
# 1530    5309               The Life and Times of Scrooge McDuck
#
#                          authors  average_rating        isbn         isbn13  \
# 6587              Bill Watterson            4.82  0740748475  9780740748479
# 4     J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
# 6589              Bill Watterson            4.76  0836221362  9780836221367
# 6                   J.K. Rowling            4.73  0439827604  9780439827607
# 6590              Bill Watterson            4.72  0836217691  9780836217698
# 6593              Bill Watterson            4.71  0740721356  9780740721359
# 6497             Patrick O'Brian            4.70  039306011X  9780393060119
# 5614                   Anonymous            4.70  0310929555  9780310929550
# 6591              Bill Watterson            4.69  0836217357  9780836217353
# 1530                    Don Rosa            4.67  0911903968  9780911903966
#
#      language_code  num_pages  ratings_count  text_reviews_count  \
# 6587           eng       1456          32213                 930
# 4              eng       2690          41428                 164
# 6589           eng        176          23875                 303
# 6              eng       3342          28242                 808
# 6590           eng        176          15365                 290
# 6593           eng         96           3613                  85
# 6497           eng       6576           1338                  81
# 5614           eng       2198           4166                 186
# 6591           eng        176          20308                 244
# 1530           eng        266           2467                 149
#
#      publication_date                   publisher
# 6587         9/6/2005   Andrews McMeel Publishing
# 4           9/13/2004                  Scholastic
# 6589         9/1/1996   Andrews McMeel Publishing
# 6           9/12/2005                  Scholastic
# 6590         9/6/1994   Andrews McMeel Publishing
# 6593        9/17/2001   Andrews McMeel Publishing
# 6497       10/17/2004       W. W. Norton  Company
# 5614        10/1/2002  Zondervan Publishing House
# 6591         9/1/1993   Andrews McMeel Publishing
# 1530         6/1/2005         Gemstone Publishing

# %% [markdown]
# ## Zählen
# Die Anzahl der Zeilen in einem Dataframe haben wir bereits in der letzten Lektion gezählt. Dafür können wir `df.shape` nutzen.
#
# Eine weitere sehr praktische Funktion ist `value_counts()`.
# Damit können wir die Häufigkeit der Ausprägungen einer Spalte erhalten.
#
# Wollen wir zum Beispiel wissen, welche die häufigsten Sprachen sind:

# %%
df.language_code.value_counts()
# Out:
# language_code
# eng      8908
# en-US    1408
# spa       218
# en-GB     214
# fre       144
# ger        99
# jpn        46
# mul        19
# zho        14
# grc        11
# por        10
# en-CA       7
# ita         5
# enm         3
# lat         3
# swe         2
# rus         2
# srp         1
# nl          1
# msa         1
# glg         1
# wel         1
# ara         1
# nor         1
# tur         1
# gla         1
# ale         1
# Name: count, dtype: int64

# %% [markdown]
# **Probiere selbst, die Häufigkeiten der `publisher` zu zählen**

# %%
# Dein Code hier

# %% [markdown]
# Natürlich können wir `value_counts()` auch mit einem Filter kombinieren. Beispielsweise können wir uns die `publisher` nur für deutsche Bücher ansehen.

# %%
df[df.language_code == "ger"].publisher.value_counts()
# Out:
# publisher
# Goldmann          8
# Heyne             8
# Lübbe             5
# Carlsen           4
# Suhrkamp          4
#                  ..
# Manesse Verlag    1
# Rowohlt Tb.       1
# Benziger          1
# dtv               1
# Fischer TB        1
# Name: count, Length: 61, dtype: int64

# %% [markdown]
# Mit der gleichen Funktion können wir uns auch die Anteile ausgeben lassen anstatt der absoluten Zahlen:

# %%
df.language_code.value_counts(normalize=True).head(5)
# Out:
# language_code
# eng      0.800863
# en-US    0.126585
# spa      0.019599
# en-GB    0.019239
# fre      0.012946
# Name: proportion, dtype: float64

# %% [markdown]
# **Welche Autoren sind in den Top 100 Büchern am öftesten vertreten?**
#
# Optional: Schließe nur Titel ein, welche mehr als 1000 ratings haben.
#
# Hinweis: Hier musst du Techniken aus verschiedenen Lektionen kombinieren.

# %%
# Dein Code hier

# %% [markdown]
# ## Erste Statistiken
# Mit Python bzw. `pandas` kannst du ganz leicht statistische Werte eines `dataframes` berechnen.

# %% [markdown]
# Was ist das längste Buch im Katalog? Was ist das kürzeste?

# %% [markdown]
# ### Min & Max

# %%
df.num_pages.max()
# Out:
# 6576

# %%
df.num_pages.min()
# Out:
# 0

# %% [markdown]
# Jetzt wissen wir zwar wie viel Seiten das längste und kürzeste Buch im Datensatz haben aber nicht deren Titel. Es gibt drei Möglichkeiten das zu lösen:

# %%
# Wir holen uns den index des Buches mit den meisten Seiten.
# Wir wissen also, dass das Buch mit den meisten Seiten a #6497 im Dataframe liegt
df.num_pages.idxmax()
# Out:
# 6497

# %%
# Wir rufen dieses Buch auf
df.iloc[6497]
# Out:
# bookID                                                         24520
# title                 The Complete Aubrey/Maturin Novels (5 Volumes)
# authors                                              Patrick O'Brian
# average_rating                                                   4.7
# isbn                                                      039306011X
# isbn13                                                 9780393060119
# language_code                                                    eng
# num_pages                                                       6576
# ratings_count                                                   1338
# text_reviews_count                                                81
# publication_date                                          10/17/2004
# publisher                                      W. W. Norton  Company
# Name: 6497, dtype: object

# %% [markdown]
# Alternativ können wir filtern

# %%
df[df.num_pages == df.num_pages.max()]
# Out:
#       bookID                                           title          authors  \
# 6497   24520  The Complete Aubrey/Maturin Novels (5 Volumes)  Patrick O'Brian
#
#       average_rating        isbn         isbn13 language_code  num_pages  \
# 6497             4.7  039306011X  9780393060119           eng       6576
#
#       ratings_count  text_reviews_count publication_date  \
# 6497           1338                  81       10/17/2004
#
#                   publisher
# 6497  W. W. Norton  Company

# %% [markdown]
# Oder sortieren

# %%
df.sort_values("num_pages", ascending=False).head(1)
# Out:
#       bookID                                           title          authors  \
# 6497   24520  The Complete Aubrey/Maturin Novels (5 Volumes)  Patrick O'Brian
#
#       average_rating        isbn         isbn13 language_code  num_pages  \
# 6497             4.7  039306011X  9780393060119           eng       6576
#
#       ratings_count  text_reviews_count publication_date  \
# 6497           1338                  81       10/17/2004
#
#                   publisher
# 6497  W. W. Norton  Company

# %% [markdown]
# ### Durchschnitte
# Wir haben oben gelernt die extreme der Verteilung zu bestimmen. Jetzt lernen wir die Mitte der Verteilung kennen.
#
# Viele von euch denken beim Durchschnitt an den Mittelwert. Es gibt aber noch weitere Durchschnitte die bei der Datenanalyse sinnvoll sind: Median und Modalwert.
#
# Eine kurze Erklärung:
# - **Mittelwert**: Summe aller Werte geteilt durch die Anzahl der summierten Werte. Auch arithmetisches Mittel genannt. Anfällig für Ausreißer.
# - **Median**: Der Wert für welchen gilt, dass die Hälfte der Beobachtungen oberhalb und die andere Hälfte unterhalb liegt. Wird nicht durch ausreißer verzerrt.
# - **Modalwert**: Gibt die am häufigsten vorkommende Beobachtung zurück. Kann im Gegensatz zu den oberen beiden auch auf Kategorische Variablen angewandt werden.

# %%
df.num_pages.mean()
# Out:
# 336.4055560550211

# %%
df.num_pages.median()
# Out:
# 299.0

# %%
df.num_pages.mode()
# Out:
# 0    288
# Name: num_pages, dtype: int64

# %% [markdown]
# **Optional: Wir sehen, dass viele Bücher in unserem Datensatz 0 Seiten haben. Das ist ein Datenfehler und verzerrt die Analyse. Wiederhole die Berechnung der Durchschnitte aber filtere diese Bücher raus.**

# %%
# Optional dein Code hier

# %% [markdown]
# ### Weitere Statistiken
# - `.count()`: Gibt die Anzahl der Beobachtungen zurück
# - `.std()`: Gibt die Standardabweichung an
# - `.quantile(q)`: Gibt den Wert für das eingegeben quantil `q` an

# %% [markdown]
# **Optional: Probiere die weiteren Statistiken aus**

# %%
# Optional: Dein Code hier

# %% [markdown]
# ### Eine schnelle Lösung für alles
#
# Weil die obigen Statistiken oft gemeinsam berechnet werden, gibt es eine Funktion die das für uns bündelt

# %%
df.num_pages.describe()
# Out:
# count    11123.000000
# mean       336.405556
# std        241.152626
# min          0.000000
# 25%        192.000000
# 50%        299.000000
# 75%        416.000000
# max       6576.000000
# Name: num_pages, dtype: float64

# %% [markdown]
# **Mache das gleiche für eine andere Spalte**

# %%
# Dein Code hier

# %% [markdown]
# ## Aggregieren mit Groupby
# **Achtung: Wichtige Lektion**
#
# Bislang haben wir die Statistiken für den Gesamten Datensatz berechnet.
#
# Oftmals möchten man diese Statistiken aber pro Gruppe berechnen, um diese miteinander vergleichen zu können. Beispielsweise könnten wir vergleichen ob deutsche Bücher im Durchschnitt länger sind als englische oder welche Autoren die erfolgreichsten Bücher schreiben.
#
# Dafür nutzen wir `groupby` gefolgt von einer Aggregationsfunktion wie `mean()`, `max()`, etc.
#
# Wichtig: Groupby verwendet man nur auf kategorische Variablen (z.B. `language_code`, `publisher`, etc.)

# %%
# Hier der Kern des neuen Codes
df.groupby("language_code").num_pages.mean()
# Out:
# language_code
# ale       512.000000
# ara       349.000000
# en-CA     252.000000
# en-GB     315.509346
# en-US     330.439631
# eng       336.797373
# enm      1060.333333
# fre       339.000000
# ger       391.979798
# gla       250.000000
# glg       741.000000
# grc       413.363636
# ita       400.600000
# jpn       190.869565
# lat       200.333333
# msa       784.000000
# mul       437.263158
# nl        744.000000
# nor       185.000000
# por       219.800000
# rus       371.500000
# spa       365.793578
# srp       222.000000
# swe       267.000000
# tur       403.000000
# wel       150.000000
# zho       321.857143
# Name: num_pages, dtype: float64

# %% [markdown]
# Um schneller zu sehen wie Englisch im Vergleich zu Deutsch steht, formatiere ich das Ergebnis noch ein wenig. Damit sehen wir schnell, dass deutsche Bücher im Durchschnitt rund 15% länger sind als Englische

# %%
df[(df.language_code.isin(["eng", "ger"])) & (df.num_pages != 0)].groupby("language_code").num_pages.mean().sort_values(ascending=False)
# Out:
# language_code
# ger    395.979592
# eng    339.042943
# Name: num_pages, dtype: float64

# %% [markdown]
# **Was sind die erfolgreichsten Autoren nach durchschnittlichem `average_rating`?**

# %%
# Dein Code hier

# %% [markdown]
# ## Spielwiese
# Wenn du Lust hast, kannst du hier  noch ein wenig mit den gelernten Funktionen experimentieren, um sie zu verinnerlichen:
